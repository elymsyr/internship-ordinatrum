# %%
import requests

def query_prometheus(prometheus_url, query):
    # Construct the Prometheus API URL for querying
    url = f"{prometheus_url}/api/v1/query"
    
    # Define the parameters for the query (PromQL query)
    params = {
        'query': query
    }
    
    # Send the request to Prometheus
    response = requests.get(url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Return the JSON data
        return response.json()
    else:
        raise Exception(f"Failed to query Prometheus: {response.status_code}, {response.text}")

# Example usage:
prometheus_url = "http://localhost:9090"  # Replace with your Prometheus server address
query = 'node_cpu_seconds_total'  # Replace with your desired PromQL query
metrics_data = query_prometheus(prometheus_url, query)
print(metrics_data)

# %%
def process_metrics_data(data):
    # Example: Extract and summarize metric values
    result = data['data']['result']
    processed_data = {}
    
    for metric in result:
        # Extract the metric name and value
        metric_name = metric['metric'].get('__name__', 'unknown_metric')
        value = float(metric['value'][1])  # Extract the value (second item)
        
        # Aggregate values (you can customize this logic)
        if metric_name in processed_data:
            processed_data[metric_name].append(value)
        else:
            processed_data[metric_name] = [value]
    
    # Example: Compute the average of each metric
    for metric_name, values in processed_data.items():
        processed_data[metric_name] = sum(values) / len(values)
    
    return processed_data

# Example processing the metrics data
processed_data = process_metrics_data(metrics_data)
print(processed_data)

# %%
def send_data_to_dotnet_web(api_url, processed_data):
    # Send a POST request with the processed data to the .NET API
    response = requests.post(api_url, json=processed_data)
    
    # Check if the request was successful
    if response.status_code == 200:
        print("Data successfully sent to .NET web application.")
    else:
        raise Exception(f"Failed to send data: {response.status_code}, {response.text}")
processed_data = {
    "metricName": "CPU Usage",
    "value": 75,
    "timestamp": "2024-11-28T14:00:00"
}
# Example usage:
api_url = "http://localhost:5001/api/monitoring/metrics"  # Replace with the correct port
send_data_to_dotnet_web(api_url, processed_data)

# %%
# import requests

# # Step 1: Query Prometheus
# def query_prometheus(prometheus_url, query):
#     url = f"{prometheus_url}/api/v1/query"
#     params = {'query': query}
#     response = requests.get(url, params=params)
    
#     if response.status_code == 200:
#         return response.json()
#     else:
#         raise Exception(f"Failed to query Prometheus: {response.status_code}, {response.text}")

# # Step 2: Process the Prometheus data
# def process_metrics_data(data):
#     result = data['data']['result']
#     processed_data = {}
    
#     for metric in result:
#         metric_name = metric['metric'].get('__name__', 'unknown_metric')
#         value = float(metric['value'][1])
        
#         if metric_name in processed_data:
#             processed_data[metric_name].append(value)
#         else:
#             processed_data[metric_name] = [value]
    
#     for metric_name, values in processed_data.items():
#         processed_data[metric_name] = sum(values) / len(values)
    
#     return processed_data

# # Step 3: Send data to .NET Web API
# def send_data_to_dotnet_web(api_url, processed_data):
#     response = requests.post(api_url, json=processed_data)
    
#     if response.status_code == 200:
#         print("Data successfully sent to .NET web application.")
#     else:
#         raise Exception(f"Failed to send data: {response.status_code}, {response.text}")

# # Example usage
# prometheus_url = "http://<PROMETHEUS_SERVER>:9090"
# query = 'node_cpu_seconds_total'
# metrics_data = query_prometheus(prometheus_url, query)
# processed_data = process_metrics_data(metrics_data)
# api_url = "http://<YOUR_DOTNET_APP>/api/monitoring/metrics"
# send_data_to_dotnet_web(api_url, processed_data)
